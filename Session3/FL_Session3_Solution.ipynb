# %% [markdown]
# <div style="display: flex; flex-direction: column; align-items: center; text-align: center; font-family: 'Avenir Next LT Pro', sans-serif; padding: 50px; background-color: #f4f4f4; border-radius: 12px; box-shadow: 0px 4px 12px rgba(0, 0, 0, 0.1);">
#     <h1 style="font-size: 50px; font-weight: bold; color: #222; margin-bottom: 10px;">Filologia Digital - Módulo V</h1>
#     <h3 style="font-size: 30px; font-weight: bold; color: #555; max-width: 80%; line-height: 1.3;">
#         Para além da edição: <span style="font-weight: normal; color: #666;">o digital na investigação linguística</span>
#     </h3>
#     <h4 style="font-size: 26px; font-weight: bold; color: #333; background-color: #e0e0e0; padding: 10px 20px; border-radius: 8px; margin-top: 25px;">Sessão 3 - Manipulação de Ficheiros, Visualização de Dados e Introdução ao Pandas</h4>
#     <img src="https://filologiadigitalcl.wordpress.com/wp-content/uploads/2024/11/figure05.png?w=1024"
#          style="width: 80%; max-width: 600px; margin-top: 30px; border-radius: 10px; box-shadow: 0px 4px 12px rgba(0, 0, 0, 0.15);">
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #f4f4f4;
#             color: #333;
#             margin: 0;
#             padding: 20px;
#             line-height: 1.6;
#         }
#         ol {
#             counter-reset: section;
#             list-style: none;
#             padding-left: 0;
#         }
#         /* First-level list */
#         ol > li {
#             counter-increment: section;
#             margin-bottom: 10px;
#             padding-left: 0;
#         }
#         ol > li::before {
#             content: counters(section, ".") " ";
#             font-weight: bold;
#         }
#         /* Second-level list */
#         ol ol {
#             counter-reset: subsection;
#             padding-left: 20px;
#             margin-top: 5px;
#         }
#         ol ol > li {
#             counter-increment: subsection;
#             margin-bottom: 5px;
#             padding-left: 10px;
#         }
#         ol ol > li::before {
#             content: counters(section, ".") "." counter(subsection) " ";
#             font-weight: bold;
#         }
#         /* Third-level list */
#         ol ol ol {
#             counter-reset: subsubsection;
#             padding-left: 40px;
#             margin-top: 5px;
#         }
#         ol ol ol > li {
#             counter-increment: subsubsection;
#             margin-bottom: 5px;
#             padding-left: 10px;
#             font-size: 0.9em; /* Make font size smaller */
#             font-weight: normal; /* Remove bold styling */
#         }
#         ol ol ol > li::before {
#             content: counters(section, ".") "." counter(subsection) "." counter(subsubsection) " ";
#             font-weight: bold;
#         }
#         a {
#             text-decoration: none;
#             color: #007BFF;
#             font-weight: bold;
#         }
#         a:hover {
#             color: #0056b3;
#         }
#         footer {
#             margin-top: 50px;
#         }
#     </style>
# </head>
# <body>
#
# <b><h2>Índice</h2></b>
# <ol start="0">
#     <li><a href="#1.">Aquecimento</a></li>
#     <li><a href="#2.">Manipulação de Ficheiros</a></li>
#     <li><a href="#3.">Visualização de dados</a></li>
#     <li><a href="#4.">Pandas com Dataset de Literatura Clássica</a></li>
#     <li><a href="#5.">Exercícios Finais</a></li>
# </ol>
#
# <footer></footer>
#
# </body>
# </html>

# %% [markdown]
# <a class='anchor' id='1.'></a>
# # **1. Aquecimento**

# %% [markdown]
# ## <a id="tp1"></a>✨ **Exercício 1**: Frequência de Palavras
# Cria uma função ``contar_frequencia`` que recebe uma frase como argumento e devolve um dicionário com a contagem de cada palavra.
# Se as duas palavras tiverem o mesmo comprimento, devolve a primeira palavra.
#
# *Dicas:*
# - Usa ``.split()`` para dividir a frase.
# - Usa um dicionário para contar.
#
# ```python
# def contar_frequencia(frase):
#     # completar código aqui
#     pass
#
# print(contar_frequencia("o sol nasce e o sol brilha"))
# # Saída esperada: {'o': 2, 'sol': 2, 'nasce': 1, 'e': 1, 'brilha': 1}
# ```

# %%
def contar_frequencia(frase):
    palavras = frase.split()  # Divide a frase em palavras
    frequencia = {}           # Dicionário para armazenar as contagens
    
    for palavra in palavras:
        if palavra in frequencia:
            frequencia[palavra] += 1
        else:
            frequencia[palavra] = 1
    
    return frequencia

# Teste da função
print(contar_frequencia("o sol nasce e o sol brilha"))  
# Saída esperada: {'o': 2, 'sol': 2, 'nasce': 1, 'e': 1, 'brilha': 1}
# Out:
# {'o': 2, 'sol': 2, 'nasce': 1, 'e': 1, 'brilha': 1}

# %% [markdown]
# ## <a id="tp2"></a>✨ **Exercício 2**: Encontrar Palavras com Mais de N Letras
# Cria uma função chamada ``palavras_maiores_que`` que recebe:
# - uma frase (string)
# - um número inteiro **n**
#
# A função deve devolver uma lista com todas as palavras da frase que tenham mais do que **n** letras.
# Exemplo:
#
# ```python
# def palavras_maiores_que(frase, n):
#     # completar código aqui
#     pass
#
# print(palavras_maiores_que("A linguística computacional é fascinante.", 5))
# # Saída esperada: ['linguística', 'computacional', 'fascinante']
# ```

# %%
def palavras_maiores_que(frase, n):
    palavras = frase.split()  # Divide a frase em palavras
    resultado = []

    for palavra in palavras:
        palavra_limpa = palavra.strip('.,!?;:()[]{}"\'')  # Remove pontuação
        if len(palavra_limpa) > n:
            resultado.append(palavra_limpa)
    
    return resultado

# Teste da função
print(palavras_maiores_que("A linguística computacional é fascinante.", 5))
# Saída esperada: ['linguística', 'computacional', 'fascinante']
# Out:
# ['linguística', 'computacional', 'fascinante']

# %% [markdown]
# <a class='anchor' id='2.'></a>
# # **2. Manipulação de Ficheiros**
#
# Será usado um breve excerto de: [Dom Casmurro, Machado de Assis](https://www.gutenberg.org/cache/epub/55752/pg55752-images.html)

# %% [markdown]
# <a class='anchor' id='2.1.'></a>
# ## **2.1. Caracteres Especiais e Sequências de Escape**

# %% [markdown]
# Ao trabalhar com ficheiros de texto é comum lidarmos com **sequências de escape** — combinações de caracteres especiais iniciadas com uma barra invertida `\`.
#
# Estas sequências permitem representar **caracteres invisíveis ou especiais**, como quebras de linha, tabulações, aspas, entre outros.
#
# **Tabela de Sequências de Escape em Python**
#
# | Sequência | Significado                         | Exemplo (String)             | Resultado real                   |
# |-----------|-------------------------------------|-------------------------------|----------------------------------|
# | `\n`      | Nova linha (*newline*)              | `"linha 1\nlinha 2"`          | linha 1 <br> linha 2             |
# | `\t`      | Tabulação horizontal                | `"palavra1\tpalavra2"`        | palavra1    palavra2             |
# | `\\`      | Barra invertida literal (`\`)       | `"c:\\ficheiro\\texto.txt"`   | c:\ficheiro\texto.txt            |

# %%
# Exemplo com \n (nova linha) e \t (tabulação)
print("Esta é a primeira linha.\nEsta é a segunda linha.\n")
print("Nome:\tMachado de Assis")
# Out:
# Esta é a primeira linha.
# Esta é a segunda linha.
#
# Nome:	Machado de Assis

# %%
# Caminhos em Windows com \\ para não quebrar
caminho = "C:\\Documentos\\obras\\text.txt"
print(caminho)

# Aspas dentro de strings
frase = "Ele disse: \"A leitura liberta\"."
print(frase)
# Out:
# C:\Documentos\obras\text.txt
# Ele disse: "A leitura liberta".

# %%
# o \ não é interpretado
caminho = r"c:\ficheiro\texto.txt"
caminho
# Out:
# 'c:\\ficheiro\\texto.txt'

# %% [markdown]
# <a class='anchor' id='2.2.'></a>
# ## **2.2. Manipulação de Ficheiros em Python**

# %% [markdown]
# Quando trabalhamos com grandes quantidades de texto é comum termos de **ler, escrever e processar ficheiros de texto**.
# O python oferece uma forma simples de interagir com ficheiros através da função `open()`.
#
# | Conceito                        | Descrição                                                                 |
# |--------------------------------|---------------------------------------------------------------------------|
# | `open('ficheiro.txt')`         | Abre um ficheiro em modo de leitura (por omissão).                        |
# | `open('ficheiro.txt', 'w')`    | Abre um ficheiro em modo de escrita (apaga conteúdo anterior).            |
# | `open('ficheiro.txt', 'a')`    | Abre um ficheiro em modo de adição (escreve no final).                    |
# | `open('ficheiro.txt', 'r')`    | Abre um ficheiro em modo de leitura.                                      |
# | `read()`                       | Lê todo o conteúdo do ficheiro.                                           |
# | `readline()`                   | Lê uma linha do ficheiro.                                                 |
# | `readlines()`                  | Lê todas as linhas e devolve uma lista.                                   |
# | `write(texto)`                 | Escreve texto no ficheiro.                                                |
# | `close()`                      | Fecha o ficheiro. É importante para libertar recursos.                    |
# | `with open(...) as f:`         | Abre o ficheiro de forma segura (fecha automaticamente após uso).         |

# %% [markdown]
# **Exemplo 1: Ler um ficheiro linha a linha**

# %%
x = open('text.txt', 'r', encoding='utf-8')
for i in x:
    print(i.strip())
# Out:
# Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no trem da Central um rapaz aqui do bairro, que eu conheço de vista e de chapéo.
# Comprimentou-me, sentou-se ao pé de mim, falou da lua e dos ministros, e acabou recitando-me versos.
# A viagem era curta, e os versos póde ser que não fossem inteiramente maus.
# Succedeu, porém, que como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto bastou para que elle interrompesse a leitura e mettesse os versos no bolso.
# Continue, disse eu accordando.
# Já acabei, murmurou elle.
# São muito bonitos.
# Vi-lhe fazer um gesto para tiral-os outra vez do bolso, mas não passou do gesto; estava amuado.
# No dia seguinte entrou a dizer de mim nomes feios, e acabou alcunhando-me Dom Casmurro.
# Os visinhos, que não gostam dos meus habitos reclusos e calados, deram curso á alcunha, que afinal pegou.
# ...

# %%
texto = ""

with open('text.txt', 'r', encoding='utf-8') as ficheiro:
    for linha in ficheiro:
        texto += linha
print(texto)
# Out:
# Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no trem da Central um rapaz aqui do bairro, que eu conheço de vista e de chapéo.
# Comprimentou-me, sentou-se ao pé de mim, falou da lua e dos ministros, e acabou recitando-me versos.
# A viagem era curta, e os versos póde ser que não fossem inteiramente maus.
# Succedeu, porém, que como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto bastou para que elle interrompesse a leitura e mettesse os versos no bolso.
# Continue, disse eu accordando.
# Já acabei, murmurou elle.
# São muito bonitos.
# Vi-lhe fazer um gesto para tiral-os outra vez do bolso, mas não passou do gesto; estava amuado.
# No dia seguinte entrou a dizer de mim nomes feios, e acabou alcunhando-me Dom Casmurro.
# Os visinhos, que não gostam dos meus habitos reclusos e calados, deram curso á alcunha, que afinal pegou.
# ...

# %% [markdown]
# **Exemplo 2: Escrever num ficheiro**

# %%
with open('novo_ficheiro.txt', 'w', encoding='utf-8') as f:  # Cuidado que apaga o que está previamente no ficheiro
    f.write("\tPrimeira linha.\n")
    f.write("Segunda linha.")

# %% [markdown]
# **Exemplo 2: Adicionar texto a um ficheiro**

# %%
with open('text.txt', 'a', encoding='utf-8') as f:  # Aqui vamos acrescentar ao ficheiro existente
    f.write("\nTeste 1.")

# %%
with open('text.txt', 'r', encoding='utf-8') as ficheiro:
    for linha in ficheiro:
        print(linha.strip())
# Out:
# Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no trem da Central um rapaz aqui do bairro, que eu conheço de vista e de chapéo.
# Comprimentou-me, sentou-se ao pé de mim, falou da lua e dos ministros, e acabou recitando-me versos.
# A viagem era curta, e os versos póde ser que não fossem inteiramente maus.
# Succedeu, porém, que como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto bastou para que elle interrompesse a leitura e mettesse os versos no bolso.
# Continue, disse eu accordando.
# Já acabei, murmurou elle.
# São muito bonitos.
# Vi-lhe fazer um gesto para tiral-os outra vez do bolso, mas não passou do gesto; estava amuado.
# No dia seguinte entrou a dizer de mim nomes feios, e acabou alcunhando-me Dom Casmurro.
# Os visinhos, que não gostam dos meus habitos reclusos e calados, deram curso á alcunha, que afinal pegou.
# ...

# %% [markdown]
# **Exemplo 3: Remover apenas a linha adicionada**

# %%
# Supondo que queres remover a linha "Linha extra"
with open('text.txt', 'r', encoding='utf-8') as f:
    linhas = f.readlines()
linhas
# Out:
# ['Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no trem da Central um rapaz aqui do bairro, que eu conheço de vista e de chapéo.\n',
#  'Comprimentou-me, sentou-se ao pé de mim, falou da lua e dos ministros, e acabou recitando-me versos.\n',
#  'A viagem era curta, e os versos póde ser que não fossem inteiramente maus.\n',
#  'Succedeu, porém, que como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto bastou para que elle interrompesse a leitura e mettesse os versos no bolso.\n',
#  'Continue, disse eu accordando.\n',
#  'Já acabei, murmurou elle.\n',
#  'São muito bonitos.\n',
#  'Vi-lhe fazer um gesto para tiral-os outra vez do bolso, mas não passou do gesto; estava amuado.\n',
#  'No dia seguinte entrou a dizer de mim nomes feios, e acabou alcunhando-me Dom Casmurro.\n',
#  'Os visinhos, que não gostam dos meus habitos reclusos e calados, deram curso á alcunha, que afinal pegou.\n',
# ...

# %%
linhas_filtradas = [linha.strip() for linha in linhas if linha.strip() != 'Teste 1.']
linhas_filtradas
# Out:
# ['Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no trem da Central um rapaz aqui do bairro, que eu conheço de vista e de chapéo.',
#  'Comprimentou-me, sentou-se ao pé de mim, falou da lua e dos ministros, e acabou recitando-me versos.',
#  'A viagem era curta, e os versos póde ser que não fossem inteiramente maus.',
#  'Succedeu, porém, que como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto bastou para que elle interrompesse a leitura e mettesse os versos no bolso.',
#  'Continue, disse eu accordando.',
#  'Já acabei, murmurou elle.',
#  'São muito bonitos.',
#  'Vi-lhe fazer um gesto para tiral-os outra vez do bolso, mas não passou do gesto; estava amuado.',
#  'No dia seguinte entrou a dizer de mim nomes feios, e acabou alcunhando-me Dom Casmurro.',
#  'Os visinhos, que não gostam dos meus habitos reclusos e calados, deram curso á alcunha, que afinal pegou.',
# ...

# %%
for linha in range(len(linhas_filtradas) - 1):
    linhas_filtradas[linha] += '\n'  # Adiciona uma nova linha ao final de cada linha filtrada
linhas_filtradas
# Out:
# ['Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no trem da Central um rapaz aqui do bairro, que eu conheço de vista e de chapéo.\n',
#  'Comprimentou-me, sentou-se ao pé de mim, falou da lua e dos ministros, e acabou recitando-me versos.\n',
#  'A viagem era curta, e os versos póde ser que não fossem inteiramente maus.\n',
#  'Succedeu, porém, que como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto bastou para que elle interrompesse a leitura e mettesse os versos no bolso.\n',
#  'Continue, disse eu accordando.\n',
#  'Já acabei, murmurou elle.\n',
#  'São muito bonitos.\n',
#  'Vi-lhe fazer um gesto para tiral-os outra vez do bolso, mas não passou do gesto; estava amuado.\n',
#  'No dia seguinte entrou a dizer de mim nomes feios, e acabou alcunhando-me Dom Casmurro.\n',
#  'Os visinhos, que não gostam dos meus habitos reclusos e calados, deram curso á alcunha, que afinal pegou.\n',
# ...

# %%
with open('text.txt', 'w', encoding='utf-8') as f:
    f.writelines(linhas_filtradas)

# %% [markdown]
# **Exemplo 4: Escrever várias linhas de uma só vez**

# %%
linhas = ["Linha 1\n", "Linha 2\n", "Linha 3"]
with open('novo_ficheiro.txt', 'w', encoding='utf-8') as f:
    f.writelines(linhas)

# %% [markdown]
# <a class='anchor' id='3.'></a>
# # **3. Visualização de dados**

# %% [markdown]
# **Pré-exercício: Frequência de Palavras**
# - Contar a frequência das palavras mais comuns no ficheiro ``text.txt``, com o objetivo de criar representações visuais dos dados.

# %% [markdown]
# > Método 1

# %%
texto = ""

with open('text.txt', 'r', encoding='utf-8') as ficheiro:
    for linha in ficheiro:
        texto += linha.strip()
        texto += " "

contar_frequencia(texto)
# Out:
# {'Uma': 1,
#  'noite': 1,
#  'destas,': 1,
#  'vindo': 1,
#  'da': 5,
#  'cidade': 1,
#  'para': 6,
#  'o': 4,
#  'Engenho': 2,
#  'Novo,': 2,
#  'encontrei': 1,
#  'no': 4,
#  'trem': 2,
#  'Central': 1,
#  'um': 2,
#  'rapaz': 1,
#  'aqui': 3,
#  'do': 7,
#  'bairro,': 1,
#  'que': 12,
#  'eu': 3,
#  'conheço': 1,
#  'de': 6,
#  'vista': 1,
#  'e': 11,
#  'chapéo.': 1,
#  'Comprimentou-me,': 1,
#  'sentou-se': 1,
#  'ao': 2,
#  'pé': 1,
#  'mim,': 1,
#  'falou': 1,
#  'lua': 1,
#  'dos': 3,
#  'ministros,': 1,
#  'acabou': 2,
#  'recitando-me': 1,
#  'versos.': 1,
#  'A': 1,
#  'viagem': 1,
#  'era': 1,
#  'curta,': 1,
#  'os': 3,
#  'versos': 2,
#  'póde': 1,
#  'ser': 1,
#  'não': 9,
#  'fossem': 1,
#  'inteiramente': 1,
#  'maus.': 1,
#  'Succedeu,': 1,
#  'porém,': 1,
#  'como': 1,
#  'estava': 2,
#  'cançado,': 1,
#  'fechei': 1,
#  'olhos': 1,
#  'tres': 1,
#  'ou': 1,
#  'quatro': 1,
#  'vezes;': 1,
#  'tanto': 1,
#  'bastou': 1,
#  'elle': 1,
#  'interrompesse': 1,
# ...

# %% [markdown]
# > Método 2

# %%
import re

palavras_contar = []
dict_contar = {}

with open('text.txt', 'r', encoding='utf-8') as ficheiro:
    for linha in ficheiro:
        linha_limpa = linha.strip()
        for palavra in linha_limpa.split():
            texto_limpo = re.sub(r'[^\w\s]', '', palavra.lower())
            palavras_contar.append(texto_limpo)

for palavra in palavras_contar:
    if palavra in dict_contar:
        dict_contar[palavra] += 1
    else:
        dict_contar[palavra] = 1

print(dict_contar)
# Out:
# {'uma': 1, 'noite': 1, 'destas': 1, 'vindo': 1, 'da': 5, 'cidade': 3, 'para': 6, 'o': 5, 'engenho': 2, 'novo': 2, 'encontrei': 1, 'no': 5, 'trem': 2, 'central': 1, 'um': 2, 'rapaz': 1, 'aqui': 3, 'do': 7, 'bairro': 1, 'que': 12, 'eu': 3, 'conheço': 1, 'de': 6, 'vista': 1, 'e': 12, 'chapéo': 1, 'comprimentoume': 1, 'sentouse': 1, 'ao': 2, 'pé': 1, 'mim': 2, 'falou': 1, 'lua': 1, 'dos': 3, 'ministros': 1, 'acabou': 2, 'recitandome': 1, 'versos': 3, 'a': 8, 'viagem': 1, 'era': 1, 'curta': 1, 'os': 4, 'póde': 1, 'ser': 1, 'não': 10, 'fossem': 1, 'inteiramente': 1, 'maus': 1, 'succedeu': 1, 'porém': 1, 'como': 1, 'estava': 2, 'cançado': 1, 'fechei': 1, 'olhos': 1, 'tres': 1, 'ou': 1, 'quatro': 1, 'vezes': 1, 'tanto': 2, 'bastou': 1, 'elle': 2, 'interrompesse': 1, 'leitura': 1, 'mettesse': 1, 'bolso': 2, 'continue': 1, 'disse': 1, 'accordando': 1, 'já': 1, 'acabei': 1, 'murmurou': 1, 'são': 1, 'muito': 1, 'bonitos': 1, 'vilhe': 1, 'fazer': 1, 'gesto': 2, 'tiralos': 1, 'outra': 1, 'vez': 1,
# ...

# %%
import matplotlib.pyplot as plt

plt.bar(dict_contar.keys(), dict_contar.values())
# Out:
# <BarContainer object of 213 artists>

# %% [markdown]
# <a class='anchor' id='3.1.'></a>
# ## **3.1. Visualização com Matplotlib**
# Para prosseguir com esta secção, será necessário instalar a biblioteca Matplotlib, uma das bibliotecas mais utilizadas em Python para visualização de dados.
#
# O Matplotlib permite criar gráficos simples, personalizados e versáteis, sendo uma excelente ferramenta para representar dados de forma visual.

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <a class='anchor' id='3.1.1.'></a>
# ### **3.1.1. Barplot**
# - Abaixo apresenta-se uma função simples para gerar um gráfico de barras (barplot). Iremos visualizar a frequência de palavras contidas no ficheiro, seguindo-se a representação das 10 palavras mais frequentes.

# %%
def plot_barplot(abcissas, odenadas, titulo='Palavras mais frequentes', horizontal=False):
    plt.figure(figsize=(10, 6))
    if horizontal:
        plt.barh(abcissas, odenadas, color='skyblue')
        plt.xlabel('Frequência')
        plt.ylabel('Palavras')
    else:
        plt.bar(abcissas, odenadas, color='skyblue')
        plt.xlabel('Palavras')
        plt.ylabel('Frequência')
    plt.title(titulo)
    # plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **a) Visualizar a frequência de palavras**

# %%
plot_barplot(dict_contar.keys(), dict_contar.values())

# %% [markdown]
# **b) Visualizar Top10 palavras mais frequentes**

# %%
high_contar = {}

for palavra, frequencia in dict_contar.items():
    if frequencia >= 5:
        high_contar[palavra] = frequencia

plot_barplot(list(high_contar.keys()), list(high_contar.values()), titulo='Top10 Palavras Mais Frequentes', horizontal=True)

# %% [markdown]
# <a class='anchor' id='3.1.2.'></a>
# ### **3.1.2. Lineplot**
# - O lineplot (gráfico de linhas) é uma representação visual que mostra a evolução ou variação de um valor ao longo de um eixo, normalmente o tempo ou a posição.
# - Neste caso, vamos utilizar um lineplot para visualizar o número de caracteres por linha no ficheiro de texto. Esta abordagem ajuda a perceber como varia o comprimento das linhas ao longo da obra, o que pode ser relevante para identificar estruturas formais, mudanças de estilo ou seções distintas.

# %%
def plot_lineplot(abcissas, odenadas, titulo='Palavras mais frequentes'):
    # Criar o gráfico de linha
    plt.figure(figsize=(10, 6))
    plt.plot(abcissas, odenadas, marker='o', linestyle='-', color='blue', linewidth=2, markersize=8)

    # Personalização do gráfico
    plt.title(titulo)
    plt.xlabel('Tempo')
    plt.ylabel('Frequencia') 
    plt.grid(True)
    plt.legend()
    plt.tight_layout()

    # Mostrar
    plt.show()

# %%
alinea_count = {}
with open('text.txt', 'r', encoding='utf-8') as file:
    for number, linha in enumerate(file):
        print(f"Linha {number}: {len(linha.strip())}")
        alinea_count[number] = len(linha.strip())
plot_lineplot(alinea_count.keys(), alinea_count.values(), titulo='Contagem de Alíneas no Ficheiro')
# Out:
# Linha 0: 145
# Linha 1: 100
# Linha 2: 74
# Linha 3: 164
# Linha 4: 30
# Linha 5: 25
# Linha 6: 18
# Linha 7: 95
# Linha 8: 87
# Linha 9: 105
# Linha 10: 164
# Linha 11: 148
# Linha 12: 164
# Linha 13: 27
# Linha 14: 114
# Linha 15: 56
# Linha 16: 143
# Linha 17: 61
# Linha 18: 74
# Linha 19: 67
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18164\3129024882.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# <a class='anchor' id='3.1.3.'></a>
# ### **3.1.3. Pie Chart**
# - O pie chart (gráfico circular) é uma representação gráfica usada para mostrar a proporção de diferentes categorias dentro de um todo.
# - Vamos utilizá-lo para visualizar a distribuição das vogais no ficheiro de texto, permitindo perceber quais são mais frequentes. Esta análise pode ser útil em estudos linguísticos e fonológicos dentro do contexto da filologia digital.

# %%
def plot_piechart(labels, valores, titulo='Distribuição de categorias'):
    """Cria um gráfico circular a partir de categorias e respetivos valores."""
    plt.figure(figsize=(8, 8))
    plt.pie(valores, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)

    # Personalização
    plt.title(titulo)
    plt.axis('equal')  # Garante que o círculo fique redondo
    plt.tight_layout()

    # Mostrar
    plt.show()

# %%
vogal_count = {"a": 0, "e": 0, "i": 0, "o": 0, "u": 0}
with open('text.txt', 'r', encoding='utf-8') as file:
    for linha in file:
        for char in linha.lower():
            if char in vogal_count:
                vogal_count[char] += 1
plot_piechart(vogal_count.keys(), vogal_count.values(), titulo='Distribuição de Vogais no Ficheiro')

# %% [markdown]
# <a class='anchor' id='3.1.4.'></a>
# ### **3.1.4. Scatter Plot**
# - O scatter plot (gráfico de dispersão) é uma visualização que mostra a relação entre duas variáveis numéricas.
# - Neste contexto, será utilizado para representar a relação entre o número de palavras e o número de caracteres por linha do ficheiro analisado.
# - Este tipo de gráfico é útil para perceber, por exemplo, se as linhas mais longas (em caracteres) também tendem a ter mais palavras, ou se existem linhas curtas mas densas em termos linguísticos.

# %%
def plot_scatter(x, y, titulo='Relação entre variáveis', xlabel='Variável X', ylabel='Variável Y'):
    """Cria um gráfico de dispersão (scatter plot) a partir de duas listas de valores."""
    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, color='teal', alpha=0.7, edgecolors='black')

    # Personalização
    plt.title(titulo)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.tight_layout()

    # Mostrar
    plt.show()

# %%
comp_freq = {}

with open('text.txt', 'r', encoding='utf-8') as file:
    for linha in file:
        palavras = linha.strip().split()
        palavras = [palavra.strip(",.;") for palavra in palavras]
        for palavra in palavras:
            if len(palavra) in comp_freq.keys():
                comp_freq[len(palavra)] += 1
            else:
                comp_freq[len(palavra)] = 1


plot_scatter(comp_freq.keys(), comp_freq.values(),
             titulo='Comprimento das palavras vs. frequência',
             xlabel='Comprimento da palavra',
             ylabel='Frequência')

# %% [markdown]
# <a class='anchor' id='3.2.'></a>
# ## **3.2. Visualização com Seaborn**
# Seaborn é uma biblioteca de visualização de dados em Python construída sobre o Matplotlib.
# É muito utilizada para criar gráficos estatísticos bonitos e informativos com menos código.
#
# Enquanto o Matplotlib é poderoso, o Seaborn torna tarefas comuns de visualização mais fáceis e com um design moderno por defeito.

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
# Estilo visual global
sns.set_theme(style="darkgrid")

# sns.set_style("whitegrid")   # Grelha branca (bom para gráficos com eixos como barplots, lineplots)
# sns.set_style("darkgrid")    # Grelha escura (útil em fundo escuro, bom contraste)
# sns.set_style("white")       # Fundo branco sem grelha
# sns.set_style("dark")        # Fundo escuro sem grelha
# sns.set_style("ticks")       # Estilo minimalista com marcas nos eixos

# %% [markdown]
# <a class='anchor' id='3.2.1.'></a>
# ### **3.2.1. Barplot**
# - Abaixo apresenta-se uma função simples para gerar um gráfico de barras (barplot). Iremos visualizar a frequência de palavras contidas no ficheiro, seguindo-se a representação das 10 palavras mais frequentes.

# %%
# Função para barplot com Seaborn + numeração
def plot_barplot_sns(x, y, titulo='Frequência de Palavras', horizontal=False):
    plt.figure(figsize=(12, 7))
    data = list(zip(x, y))
    data = sorted(data, key=lambda item: item[1], reverse=True)
    palavras, frequencias = zip(*data)

    ax = None

    if horizontal:
        ax = sns.barplot(x=frequencias, y=palavras, palette="viridis")
        plt.xlabel('Frequência')
        plt.ylabel('Palavras')

        # Adicionar os valores no final das barras
        for i, v in enumerate(frequencias):
            ax.text(v + 0.1, i, str(v), color='black', va='center', fontweight='bold')
    else:
        ax = sns.barplot(x=palavras, y=frequencias, palette="viridis")
        plt.xlabel('Palavras')
        plt.ylabel('Frequência')
        plt.xticks(rotation=45)

        # Adicionar os valores no topo das barras
        for i, v in enumerate(frequencias):
            ax.text(i, v + 0.1, str(v), color='black', ha='center', fontweight='bold')

    plt.title(titulo, fontsize=16)
    plt.tight_layout()
    plt.show()

plot_barplot_sns(high_contar.keys(), high_contar.values(), titulo='Top10 Palavras Mais Frequentes', horizontal=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 32
#      29     plt.tight_layout()
#      30     plt.show()
# ---> 32 plot_barplot_sns(high_contar.keys(), high_contar.values(), titulo='Top10 Palavras Mais Frequentes', horizontal=True)
#
# NameError: name 'high_contar' is not defined

# %% [markdown]
# <a class='anchor' id='3.2.2.'></a>
# ### **3.2.2. Lineplot**
# - O lineplot (gráfico de linhas) é uma representação visual que mostra a evolução ou variação de um valor ao longo de um eixo, normalmente o tempo ou a posição.
# - Neste caso, vamos utilizar um lineplot para visualizar o número de caracteres por linha no ficheiro de texto. Esta abordagem ajuda a perceber como varia o comprimento das linhas ao longo da obra, o que pode ser relevante para identificar estruturas formais, mudanças de estilo ou seções distintas.

# %%
def plot_lineplot_sns(x, y, titulo='Número de Caracteres por Linha'):

    plt.figure(figsize=(14, 7))
    ax = sns.lineplot(
        x=list(x), y=list(y), 
        marker='o', 
        markersize=10, 
        linewidth=3, 
        color=sns.color_palette("deep")[0],
        markerfacecolor='black', 
        markeredgewidth=2
    )
    
    # Adicionar valores em cima dos pontos
    for xi, yi in zip(x, y):
        ax.text(xi, yi + max(y)*0.02, str(yi), ha='center', va='bottom', fontsize=12, weight='bold')
    
    ax.set_title(titulo, fontsize=20, weight='bold')
    ax.set_xlabel('Número da Linha', fontsize=14)
    ax.set_ylabel('Número de Caracteres', fontsize=14)
    ax.grid(True, which='major', linestyle='--', linewidth=0.8, alpha=0.7)
    plt.xticks(rotation=45)
    plt.tight_layout()
    
    plt.show()

# Exemplo de chamada
plot_lineplot_sns(alinea_count.keys(), alinea_count.values(), titulo='Contagem de Alíneas no Ficheiro')

# %% [markdown]
# <a class='anchor' id='3.2.3.'></a>
# ### **3.2.3. Pie Chart**
# - O pie chart (gráfico circular) é uma representação gráfica usada para mostrar a proporção de diferentes categorias dentro de um todo.
# - Vamos utilizá-lo para visualizar a distribuição das vogais no ficheiro de texto, permitindo perceber quais são mais frequentes. Esta análise pode ser útil em estudos linguísticos e fonológicos dentro do contexto da filologia digital.

# %%
def plot_piechart_beautiful(labels, valores, titulo='Distribuição de categorias'):
    plt.figure(figsize=(8, 8))
    
    # Paleta de cores Seaborn
    cores = sns.color_palette('pastel')[0:len(labels)]
    
    # Explode para destacar a maior fatia (opcional)
    explode = [0.1 if v == max(valores) else 0 for v in valores]
    
    wedges, texts, autotexts = plt.pie(
        valores,
        labels=labels,
        autopct='%1.1f%%',
        startangle=90,
        colors=cores,
        explode=explode,
        shadow=True,
        textprops={'fontsize': 14, 'weight': 'bold', 'color': 'navy'}
    )
    
    plt.title(titulo, fontsize=18, weight='bold')
    plt.axis('equal')  # Círculo perfeito
    plt.tight_layout()
    plt.show()

plot_piechart_beautiful(vogal_count.keys(), vogal_count.values(), titulo='Distribuição de Vogais no Ficheiro')

# %% [markdown]
# <a class='anchor' id='3.2.4.'></a>
# ### **3.2.4. Scatter Plot**
# - O scatter plot (gráfico de dispersão) é uma visualização que mostra a relação entre duas variáveis numéricas.
# - Neste contexto, será utilizado para representar a relação entre o número de palavras e o número de caracteres por linha do ficheiro analisado.
# - Este tipo de gráfico é útil para perceber, por exemplo, se as linhas mais longas (em caracteres) também tendem a ter mais palavras, ou se existem linhas curtas mas densas em termos linguísticos.

# %%
def plot_scatter_sns(x, y, titulo='Relação entre Comprimento de Palavra e Frequência', xlabel='Comprimento da Palavra', ylabel='Frequência'):
    plt.figure(figsize=(14, 8))
    ax = sns.scatterplot(
        x=list(x),
        y=list(y),
        s=150,                        # tamanho dos pontos
        color=sns.color_palette("dark")[2],
        edgecolor='black',
        linewidth=1,
        alpha=0.85
    )

    # Anotar os valores em cada ponto (frequência)
    for xi, yi in zip(x, y):
        ax.text(xi, yi + max(y)*0.02, str(yi), 
                ha='center', va='bottom', 
                fontsize=12, weight='bold', color='navy')

    ax.set_title(titulo, fontsize=20, weight='bold')
    ax.set_xlabel(xlabel, fontsize=14)
    ax.set_ylabel(ylabel, fontsize=14)

    # Melhorar grelha
    ax.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.tight_layout()
    plt.show()

# Chamada exemplo
plot_scatter_sns(comp_freq.keys(), comp_freq.values(),
                 titulo='Comprimento das palavras vs. frequência',
                 xlabel='Comprimento da palavra',
                 ylabel='Frequência')

# %% [markdown]
# <a class='anchor' id='3.3.'></a>
# ## **3.3. Extras**

# %% [markdown]
# <a class='anchor' id='3.3.1.'></a>
# ### **3.3.1. WordlCloud**
# - A WordCloud (ou nuvem de palavras) é uma representação visual das palavras mais frequentes num determinado texto. As palavras com maior frequência são apresentadas com um tamanho de letra superior, permitindo assim identificar rapidamente os termos mais relevantes ou recorrentes numa análise textual.
# - Este tipo de visualização é bastante útil em contextos exploratórios, como por exemplo para obter uma perceção geral de temas abordados num documento ou livro.
# - Nesta implementação, é apenas necessário fornecer uma string com o texto completo que se pretende analisar. A função tratará automaticamente da geração da nuvem com base nas repetições das palavras.

# %%
# !pip install wordcloud
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
texto = ""

with open('text.txt', 'r', encoding='utf-8') as ficheiro:
    for linha in ficheiro:
        texto += linha.strip() + "\n"
print(texto)
# Out:
# Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no trem da Central um rapaz aqui do bairro, que eu conheço de vista e de chapéo.
# Comprimentou-me, sentou-se ao pé de mim, falou da lua e dos ministros, e acabou recitando-me versos.
# A viagem era curta, e os versos póde ser que não fossem inteiramente maus.
# Succedeu, porém, que como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto bastou para que elle interrompesse a leitura e mettesse os versos no bolso.
# Continue, disse eu accordando.
# Já acabei, murmurou elle.
# São muito bonitos.
# Vi-lhe fazer um gesto para tiral-os outra vez do bolso, mas não passou do gesto; estava amuado.
# No dia seguinte entrou a dizer de mim nomes feios, e acabou alcunhando-me Dom Casmurro.
# Os visinhos, que não gostam dos meus habitos reclusos e calados, deram curso á alcunha, que afinal pegou.
# ...

# %%
from wordcloud import WordCloud

# Criar a WordCloud com fundo escuro e colormap vibrante
wordcloud = WordCloud(
    width=1000,
    height=500,
    background_color='black',     # Fundo preto
    colormap='Set2',              # Paleta de cores apelativa e contrastante
    max_font_size=120,
    min_font_size=10,
    prefer_horizontal=1.0,
    random_state=42,
    normalize_plurals=True
).generate(texto)

# Mostrar
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Nuvem de Palavras Frequentes", fontsize=20, color='black')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <a class='anchor' id='3.3.2.'></a>
# ### **3.3.2. Gráfico de Rede de Coocorrência**
# -  Gráfico de Rede de Coocorrência é uma visualização que representa a relação entre palavras com base na sua proximidade num texto. Sempre que duas palavras aparecem próximas uma da outra (dentro de uma janela definida), é criada uma ligação (ou aresta) entre elas.
# - Neste tipo de grafo, as palavras funcionam como nós (vértices), e a força da ligação entre elas é representada pela espessura das arestas, que depende da frequência com que essas palavras ocorrem juntas.
# - Esta técnica é particularmente útil para explorar estruturas semânticas e padrões de coocorrência lexical, ajudando a identificar grupos de palavras que aparecem frequentemente em conjunto. Pode ser aplicada em estudos linguísticos, análise de tópicos, estilometria ou em sistemas de recomendação textual.
# - Nesta implementação, o grafo é construído com base nas 30 coocorrências mais frequentes, considerando uma janela de ``n`` palavras (antes e depois). A visualização destaca as ligações mais significativas, permitindo uma análise visual clara das associações léxicas dominantes no texto analisado.

# %%
# !pip install networkx
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import networkx as nx
from collections import Counter
import re

def plot_coocurrence_graph(filepath='text.txt', window_size=3, top_n=30, titulo='Rede de Coocorrência de Palavras'):
    """Cria um gráfico de rede (grafo) com base na coocorrência de palavras num ficheiro de texto."""

    # Ler e pré-processar o texto
    with open(filepath, 'r', encoding='utf-8') as f:
        texto = f.read().lower()
        texto = re.sub(r'[^\w\s]', '', texto)  # Remove pontuação
        palavras = texto.split()

    # Calcular coocorrências dentro da janela definida
    coocorrencias = Counter()
    for i, palavra in enumerate(palavras):
        janela = palavras[max(i - window_size, 0): i] + palavras[i+1: i+1 + window_size]
        for vizinha in janela:
            par = tuple(sorted((palavra, vizinha)))
            coocorrencias[par] += 1

    # Selecionar os pares mais frequentes
    top_pares = dict(coocorrencias.most_common(top_n))

    # Criar grafo
    G = nx.Graph()
    for (w1, w2), peso in top_pares.items():
        G.add_edge(w1, w2, weight=peso)

    # Visualizar grafo
    plt.figure(figsize=(14, 9))
    pos = nx.spring_layout(G, k=0.9, seed=42)  # Layout com espaçamento mais claro
    edges = G.edges(data=True)
    pesos = [dados['weight'] for _, _, dados in edges]

    # Desenhar nós e arestas com gradientes
    nx.draw_networkx_nodes(G, pos, node_size=800, node_color='lightsteelblue', edgecolors='black')
    nx.draw_networkx_edges(G, pos, width=[p * 0.4 for p in pesos], alpha=0.5, edge_color='grey')
    nx.draw_networkx_labels(G, pos, font_size=11, font_weight='bold', font_family='sans-serif')

    plt.title(titulo, fontsize=18, weight='bold')
    plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_coocurrence_graph(filepath='text.txt', window_size=3, top_n=35)

# %% [markdown]
# <a class='anchor' id='4.'></a>
# # **4. Pandas com Dataset de [Literatura Clássica](https://corgis-edu.github.io/corgis/csv/classics/)**
#
# Para esta secção, vamos explorar a poderosa biblioteca Pandas, muito utilizada em ciência de dados para análise, limpeza e manipulação de dados estruturados. Para tornar o exercício mais interessante e tematicamente coerente com a filologia digital, vamos utilizar um conjunto de dados sobre obras literárias clássicas, disponibilizado pelo projeto [CORGIS](https://corgis-edu.github.io/corgis/).
#
# Este dataset inclui informações sobre centenas de textos do Project Gutenberg, tais como:
# - Título e autor da obra,
# - Número de downloads,
# - Métricas de legibilidade (e.g., Flesch-Kincaid, Linsear Write),
# - Análise de sentimentos do texto,
# - Número total de palavras, frases e parágrafos.
#
# Com estes dados, podemos:
# - Explorar padrões de popularidade literária;
# - Analisar a complexidade linguística ao longo do tempo;
# - Relacionar métricas de estilo com o impacto (downloads);
# - Criar visualizações e filtros úteis para investigação textual.
#
# A seguir, iremos:
# - Carregar o dataset diretamente da web;
# - Explorar a sua estrutura com pandas;
# - Criar visualizações descritivas e comparativas;
# - Aplicar filtros, agrupamentos e métricas úteis para análise literária.

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <a class='anchor' id='4.1.'></a>
# ## **4.1. Importar e explorar o dataset**

# %%
import pandas as pd

# Carregar o dataset de literatura clássica
url = "https://corgis-edu.github.io/corgis/datasets/csv/classics/classics.csv"
df = pd.read_csv(url)

# Mostrar o dataframe
df
# Out:
#      bibliography.congress classifications bibliography.languages  \
# 0                                       PR                     en
# 1                                       PS                     en
# 2                                    PZ,PR                     en
# 3                                       PR                     en
# 4                                       PT                     en
# ...                                    ...                    ...
# 1001                                   NaN                     en
# 1002                                   NaN                     en
# 1003                                   NaN                     en
# 1004                                   NaN                     en
# 1005                                   NaN                     en
#
#                                   bibliography.subjects  \
# 0     Sisters -- Fiction,Courtship -- Fiction,Social...
# 1     Mentally ill women -- Fiction,Feminist fiction...
# ...

# %% [markdown]
# <a class='anchor' id='4.2.'></a>
# ## **4.2. Compreender a estrutura**

# %%
print(df.shape)       # Exemplo: (Alíneas: 1006, Colunas: 38)
# Out:
# (1006, 38)

# %%
print(df.info())      # Tipos de coluna e valores não-nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 38 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   bibliography.congress classifications            847 non-null    object
#  1   bibliography.languages                           1006 non-null   object
#  2   bibliography.subjects                            851 non-null    object
#  3   bibliography.title                               1006 non-null   object
#  4   bibliography.type                                1006 non-null   object
#  5   metadata.downloads                               1006 non-null   int64
#  6   metadata.id                                      1006 non-null   int64
#  7   metadata.rank                                    1006 non-null   int64
#  8   metadata.url                                     1006 non-null   object
# ...

# %%
print(df.describe())  # Estatísticas como média, mínimo, máximo
# Out:
#        metadata.downloads   metadata.id  metadata.rank  \
# count         1006.000000   1006.000000    1006.000000
# mean          1431.373757  16512.391650     503.500000
# std           2361.420502  18336.804181     290.551487
# min              0.000000      1.000000       1.000000
# 25%            533.000000   1262.000000     252.250000
# 50%            758.500000   8134.000000     503.500000
# 75%           1308.000000  28978.000000     754.750000
# max          36576.000000  51495.000000    1006.000000
#
#        bibliography.author.birth  bibliography.author.death  \
# count                1006.000000                1006.000000
# mean                 1414.925447                1468.493042
# std                   773.309251                 790.256414
# min                  -750.000000                -650.000000
# 25%                  1564.000000                1616.000000
# 50%                  1821.000000                1885.000000
# ...

# %%
df['bibliography.languages'].unique()  # Verificar idiomas disponíveis
# Out:
# array(['en', 'de', 'es', 'la', 'tl', 'pt', 'enm', 'en,enm', 'fr', 'en,es',
#        'nl', 'ru', 'it'], dtype=object)

# %% [markdown]
# <a class='anchor' id='4.3.'></a>
# ## **4.3. Seleção e filtragem**

# %%
# Selecionar colunas relevantes
df[['bibliography.title', 'metadata.downloads', 'metrics.sentiments.polarity']]
# Out:
#                             bibliography.title  metadata.downloads  \
# 0                          Pride and Prejudice               36576
# 1                         The Yellow Wallpaper               26363
# 2             Alice's Adventures in Wonderland               18882
# 3      Frankenstein; Or, The Modern Prometheus               17128
# 4                                Metamorphosis               15683
# ...                                        ...                 ...
# 1001                      The Reluctant Heroes                   0
# 1002               Film Truth; September, 1920                   0
# 1003                                    Othmar                   0
# 1004              Church History (Volumes 1-3)                   0
# 1005  The Uncensored Letters of a Canteen Girl                   0
#
#       metrics.sentiments.polarity
# 0                        0.136713
# 1                        0.054174
# 2                        0.041079
# ...

# %%
# Filtrar por idioma (ex.: obras em inglês)
df_en = df[df['bibliography.languages'].str.contains('en')]
df_en
# Out:
#      bibliography.congress classifications bibliography.languages  \
# 0                                       PR                     en
# 1                                       PS                     en
# 2                                    PZ,PR                     en
# 3                                       PR                     en
# 4                                       PT                     en
# ...                                    ...                    ...
# 1001                                   NaN                     en
# 1002                                   NaN                     en
# 1003                                   NaN                     en
# 1004                                   NaN                     en
# 1005                                   NaN                     en
#
#                                   bibliography.subjects  \
# 0     Sisters -- Fiction,Courtship -- Fiction,Social...
# 1     Mentally ill women -- Fiction,Feminist fiction...
# ...

# %% [markdown]
# <a class='anchor' id='4.4.'></a>
# ## **4.4. Agrupamento e estatísticas**

# %%
# Média de downloads por autor
df.groupby('bibliography.author.name')['metadata.downloads'].mean().sort_values(ascending=False).head(10)
# Out:
# bibliography.author.name
# Gilman, Charlotte Perkins       13551.500000
# Machiavelli, Niccolo             9690.000000
# Vatsyayana                       8559.000000
# Douglass, Frederick              6914.000000
# Whitman, Walt                    6899.000000
# Joyce, James                     6808.666667
# Hobbes, Thomas                   6411.000000
# Kafka, Franz                     6390.333333
# Bronte, Emily                    6237.000000
# Shelley, Mary Wollstonecraft     6084.333333
# Name: metadata.downloads, dtype: float64

# %% [markdown]
# <a class='anchor' id='4.5.'></a>
# ## **4.5. Visualizações com Pandas / Matplotlib**

# %%
df['metadata.downloads'].hist(bins=20, color='skyblue')
plt.title('Distribuição de Downloads (obras em inglês)')
plt.xlabel('Downloads')
plt.ylabel('Contagem')
plt.show()

# %%
top10 = df.groupby('bibliography.author.name')['metadata.downloads'].sum().nlargest(10)
top10.plot(kind='barh', figsize=(10, 6), color='teal')
plt.title('Top10 Autores com Mais Downloads')
plt.xlabel('Total de Downloads')
plt.ylabel('Autor')
plt.gca().invert_yaxis()
plt.show()

# %%
df_scatter = df.dropna(subset=['metrics.difficulty.linsear write formula', 'metadata.downloads'])
plt.figure(figsize=(8, 5))
plt.scatter(x=df_scatter['metrics.difficulty.linsear write formula'],
            y=df_scatter['metadata.downloads'],
            alpha=0.6, color='purple')
plt.title('Legibilidade vs. Popularidade')
plt.xlabel('Linsear Write Score')
plt.ylabel('Downloads')
plt.grid(True)
plt.show()

# %% [markdown]
# <a class='anchor' id='5.'></a>
#
# # **5. Exercícios Finais**
# **1.** Para a realização dos exercícios finais, iremos fazer o download da obra completa Dom Casmurro, com o intuito de realizar uma análise detalhada e exploratória deste texto clássico.
# **2.** No segundo exercício, será solicitada uma análise mais aprofundada e complexa sobre o conjunto de dados da [Literatura Clássica](https://corgis-edu.github.io/corgis/csv/classics/), aplicando técnicas avançadas de manipulação e visualização de dados com o Pandas.

# %% [markdown]
# ## **Exercicio 1**
# - Neste exemplo, vamos demonstrar como obter o texto completo da obra Dom Casmurro diretamente do site do Project Gutenberg, utilizando a biblioteca ``requests`` do Python. Esta abordagem permite fazer o download automático do ficheiro de texto para posterior análise e manipulação.

# %%
# !pip install requests
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

url = "https://www.gutenberg.org/ebooks/55752.txt.utf-8"

try:
    resp = requests.get(url, timeout=15)  # timeout de 15 segundos
    resp.encoding = 'utf-8'

    if resp.status_code == 200:
        texto = resp.text
        with open("dom_casmurro.txt", "w", encoding="utf-8") as f:
            f.write(texto)
        print("Ficheiro 'dom_casmurro.txt' criado com sucesso!")
    else:
        print("Erro ao descarregar:", resp.status_code)

except requests.exceptions.ConnectTimeout:
    print("Ligação expirada: o servidor não respondeu a tempo.")
except requests.exceptions.RequestException as e:
    print(f"Erro ao tentar aceder ao recurso: {e}")
# Out:
# Ficheiro 'dom_casmurro.txt' criado com sucesso!

# %%
def limpar_e_atualizar_ficheiro(filepath):
    with open(filepath, encoding='utf-8') as f:
        linhas = f.readlines()
    
    start_idx = 0
    end_idx = len(linhas)
    
    # Encontrar início do texto real
    for i, linha in enumerate(linhas):
        if 'Do titulo.' in linha:
            start_idx = i + 1
            break
    
    # Encontrar fim do texto real
    for i, linha in enumerate(linhas):
        if 'FIM' in linha:
            end_idx = i
            break
    
    # Extrair texto principal e limpar espaços e linhas vazias
    texto_limpo = [linha.strip() for linha in linhas[start_idx:end_idx] if linha.strip()]
    
    # Sobrescrever o ficheiro com o texto limpo
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write("\n".join(texto_limpo))

# Chama a função para atualizar o ficheiro
limpar_e_atualizar_ficheiro("dom_casmurro.txt")

print("Ficheiro 'dom_casmurro.txt' atualizado com texto limpo!")
# Out:
# Ficheiro 'dom_casmurro.txt' atualizado com texto limpo!

# %% [markdown]
# **a) Limpeza do Texto e Contagem de Palavras**
# - **Objetivo**: Limpar o texto, remover pontuação e caracteres especiais, e contar as palavras mais frequentes.

# %%
import re
with open("dom_casmurro.txt", "r", encoding="utf-8") as f:
    texto = f.read().strip()
    texto = re.sub(r'\W', ' ', texto)
    texto = re.sub(r'\_', '', texto)
    texto = re.sub(r'\s+', ' ', texto)
print(texto)

texto_dividido = texto.split()
from collections import Counter
contagem_palavras = Counter(texto_dividido)
print(contagem_palavras.most_common(10))
# Out:
# Uma noite destas vindo da cidade para o Engenho Novo encontrei no trem da Central um rapaz aqui do bairro que eu conheço de vista e de chapéo Comprimentou me sentou se ao pé de mim falou da lua e dos ministros e acabou recitando me versos A viagem era curta e os versos póde ser que não fossem inteiramente maus Succedeu porém que como eu estava cançado fechei os olhos tres ou quatro vezes tanto bastou para que elle interrompesse a leitura e mettesse os versos no bolso Continue disse eu accordando Já acabei murmurou elle São muito bonitos Vi lhe fazer um gesto para tiral os outra vez do bolso mas não passou do gesto estava amuado No dia seguinte entrou a dizer de mim nomes feios e acabou alcunhando me Dom Casmurro Os visinhos que não gostam dos meus habitos reclusos e calados deram curso á alcunha que afinal pegou Nem por isso me zanguei Contei a anecdota aos amigos da cidade e elles por graça chamam me assim alguns em bilhetes Dom Casmurro domingo vou jantar com você Vou para Petropol
# ...

# %% [markdown]
# **b) Análise do Comprimento das Frases**
# - **Objetivo**: Medir quantas palavras tem cada frase e visualizar a variação ao longo do texto.

# %%
comprimento = {}

with open("dom_casmurro.txt", "r", encoding="utf-8") as f:
    for numero, linha in enumerate(f):
        comprimento[numero] = len(linha.strip())

plot_barplot(comprimento.keys(), comprimento.values(), titulo='Comprimento de Alíneas no Ficheiro')

# %% [markdown]
# **c) Distribuição do Comprimento das Palavras**
# - **Objetivo**: Explorar o comprimento das palavras e visualizar a distribuição.

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Ler o ficheiro e separar por palavras
with open("dom_casmurro.txt", "r", encoding="utf-8") as f:
    texto = f.read()

palavras = texto.split()

# Calcular o comprimento de cada palavra
comprimentos = [len(p) for p in palavras if p.strip() != ""]

# Contar frequências
contagem = Counter(comprimentos)

# Plot
plt.bar(contagem.keys(), contagem.values())
plt.xlabel("Comprimento da palavra (número de letras)")
plt.ylabel("Frequência")
plt.title("Distribuição do comprimento das palavras")
plt.show()

# %% [markdown]
# **d) Análise das Vogais**
# - **Objetivo**: Contar as vogais no texto e visualizar a distribuição.

# %%
from collections import Counter
import matplotlib.pyplot as plt

vogais = "aeiou"

# Ler o ficheiro e passar para minúsculas
with open("dom_casmurro.txt", "r", encoding="utf-8") as f:
    texto = f.read().lower()

# Contar vogais
contagem_vogais = Counter(c for c in texto if c in vogais)

# Plot
plt.bar(contagem_vogais.keys(), contagem_vogais.values())
plt.xlabel("Vogal")
plt.ylabel("Frequência")
plt.title("Distribuição das Vogais no Texto")
plt.show()

# %% [markdown]
# **d) Fazer um WordCloud com as palavras mais importantes**
# - **Objetivo**: Fazer uma visualização das palavras mais frequentes, retirando as stopwords

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import nltk

# Garantir que as stopwords estão disponíveis
nltk.download('stopwords')

# Definir stopwords em português
stop_words = set(stopwords.words('portuguese'))

# Ler o ficheiro
with open("dom_casmurro.txt", "r", encoding="utf-8") as f:
    texto = f.read().lower()

# Criar a WordCloud
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white",
    stopwords=stop_words,
    collocations=False
).generate(texto)

# Mostrar
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("WordCloud - Palavras mais frequentes (sem stopwords)")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\diogo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## **Exercicio 2**
# - No segundo exercício, será solicitada uma análise mais aprofundada e complexa sobre o conjunto de dados da [Literatura Clássica](https://corgis-edu.github.io/corgis/csv/classics/), aplicando técnicas de manipulação e visualização de dados com o Pandas.

# %%
# !pip install seaborn matplotlib pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Parte I - Pandas

# %% [markdown]
# **a) Carregar o dataset e mostrar as primeiras linhas**
# - Carrega o ficheiro CSV para um DataFrame pandas e mostra as 5 primeiras linhas, e as 5 últimas, para entender a estrutura dos dados.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("classics.csv", encoding='utf-8', header=0, sep=',')
df
# Out:
#      bibliography.congress classifications bibliography.languages  \
# 0                                       PR                     en
# 1                                       PS                     en
# 2                                    PZ,PR                     en
# 3                                       PR                     en
# 4                                       PT                     en
# ...                                    ...                    ...
# 1001                                   NaN                     en
# 1002                                   NaN                     en
# 1003                                   NaN                     en
# 1004                                   NaN                     en
# 1005                                   NaN                     en
#
#                                   bibliography.subjects  \
# 0     Sisters -- Fiction,Courtship -- Fiction,Social...
# 1     Mentally ill women -- Fiction,Feminist fiction...
# ...

# %% [markdown]
# **b) Informações gerais e tipos de dados**
# - Analisar a estrutura do dataset, tipos de colunas e valores nulos.

# %%
# df["metrics.difficulty.automated readability index"] = df["metrics.difficulty.automated readability index"].astype(int)
df.dtypes
# Out:
# bibliography.congress classifications               object
# bibliography.languages                              object
# bibliography.subjects                               object
# bibliography.title                                  object
# bibliography.type                                   object
# metadata.downloads                                   int64
# metadata.id                                          int64
# metadata.rank                                        int64
# metadata.url                                        object
# bibliography.author.birth                            int64
# bibliography.author.death                            int64
# bibliography.author.name                            object
# bibliography.publication.day                         int64
# bibliography.publication.full                       object
# bibliography.publication.month                       int64
# bibliography.publication.month name                 object
# ...

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# bibliography.congress classifications    159
# bibliography.subjects                    155
# dtype: int64

# %%
df.shape
# Out:
# (1006, 38)

# %%
df.describe()
# Out:
#        metadata.downloads   metadata.id  metadata.rank  \
# count         1006.000000   1006.000000    1006.000000
# mean          1431.373757  16512.391650     503.500000
# std           2361.420502  18336.804181     290.551487
# min              0.000000      1.000000       1.000000
# 25%            533.000000   1262.000000     252.250000
# 50%            758.500000   8134.000000     503.500000
# 75%           1308.000000  28978.000000     754.750000
# max          36576.000000  51495.000000    1006.000000
#
#        bibliography.author.birth  bibliography.author.death  \
# count                1006.000000                1006.000000
# mean                 1414.925447                1468.493042
# std                   773.309251                 790.256414
# min                  -750.000000                -650.000000
# 25%                  1564.000000                1616.000000
# 50%                  1821.000000                1885.000000
# ...

# %% [markdown]
# **c) Limpeza de colunas irrelevantes**
# - Eliminar colunas pouco informativas (ex. ``URLs``, ``IDs``).

# %%
df.columns
# Out:
# Index(['bibliography.congress classifications', 'bibliography.languages',
#        'bibliography.subjects', 'bibliography.title', 'bibliography.type',
#        'metadata.downloads', 'metadata.id', 'metadata.rank', 'metadata.url',
#        'bibliography.author.birth', 'bibliography.author.death',
#        'bibliography.author.name', 'bibliography.publication.day',
#        'bibliography.publication.full', 'bibliography.publication.month',
#        'bibliography.publication.month name', 'bibliography.publication.year',
#        'metadata.formats.total', 'metadata.formats.types',
#        'metrics.difficulty.automated readability index',
#        'metrics.difficulty.coleman liau index',
#        'metrics.difficulty.dale chall readability score',
#        'metrics.difficulty.difficult words',
#        'metrics.difficulty.flesch kincaid grade',
#        'metrics.difficulty.flesch reading ease',
#        'metrics.difficulty.gunning fog',
# ...

# %%
df.dropna(subset=['metadata.url', 'metadata.id', 'bibliography.congress classifications'], inplace=True)
df.columns
# Out:
# Index(['bibliography.congress classifications', 'bibliography.languages',
#        'bibliography.subjects', 'bibliography.title', 'bibliography.type',
#        'metadata.downloads', 'metadata.id', 'metadata.rank', 'metadata.url',
#        'bibliography.author.birth', 'bibliography.author.death',
#        'bibliography.author.name', 'bibliography.publication.day',
#        'bibliography.publication.full', 'bibliography.publication.month',
#        'bibliography.publication.month name', 'bibliography.publication.year',
#        'metadata.formats.total', 'metadata.formats.types',
#        'metrics.difficulty.automated readability index',
#        'metrics.difficulty.coleman liau index',
#        'metrics.difficulty.dale chall readability score',
#        'metrics.difficulty.difficult words',
#        'metrics.difficulty.flesch kincaid grade',
#        'metrics.difficulty.flesch reading ease',
#        'metrics.difficulty.gunning fog',
# ...

# %% [markdown]
# **d) Filtrar livros escritos em inglês**
# - Selecionar apenas os livros cuja língua principal seja o inglês.

# %%
df_eng = df[df["bibliography.languages"] == "en"]
df_eng.dropna(subset=['bibliography.languages'], inplace=True)
df_eng
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18164\3521524965.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eng.dropna(subset=['bibliography.languages'], inplace=True)
#     bibliography.congress classifications bibliography.languages  \
# 0                                      PR                     en
# 1                                      PS                     en
# 2                                   PZ,PR                     en
# 3                                      PR                     en
# 4                                      PT                     en
# ..                                    ...                    ...
# 985                                    PR                     en
# 986                                    GR                     en
# ...

# %% [markdown]
# **e) Ordenar por número de downloads**
# - Obter os 10 livros mais descarregados.

# %%
df_eng.sort_values(by='metadata.downloads', ascending=False, inplace=True)
df_eng.head(10)
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18164\2791641942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eng.sort_values(by='metadata.downloads', ascending=False, inplace=True)
#   bibliography.congress classifications bibliography.languages  \
# 0                                    PR                     en
# 1                                    PS                     en
# 2                                 PZ,PR                     en
# 3                                    PR                     en
# 4                                    PT                     en
# 5                                    PS                     en
# 6                                    PR                     en
# 7                                 PZ,PS                     en
# ...

# %% [markdown]
# **f) Contar livros por autor**
# - **Objetivo:** Ver que autores têm mais livros no dataset.

# %%
df_eng.columns
# Out:
# Index(['bibliography.congress classifications', 'bibliography.languages',
#        'bibliography.subjects', 'bibliography.title', 'bibliography.type',
#        'metadata.downloads', 'metadata.id', 'metadata.rank', 'metadata.url',
#        'bibliography.author.birth', 'bibliography.author.death',
#        'bibliography.author.name', 'bibliography.publication.day',
#        'bibliography.publication.full', 'bibliography.publication.month',
#        'bibliography.publication.month name', 'bibliography.publication.year',
#        'metadata.formats.total', 'metadata.formats.types',
#        'metrics.difficulty.automated readability index',
#        'metrics.difficulty.coleman liau index',
#        'metrics.difficulty.dale chall readability score',
#        'metrics.difficulty.difficult words',
#        'metrics.difficulty.flesch kincaid grade',
#        'metrics.difficulty.flesch reading ease',
#        'metrics.difficulty.gunning fog',
# ...

# %%
df_eng["bibliography.author.name"].value_counts()
# Out:
# bibliography.author.name
# Unknown                                32
# Shakespeare, William                   19
# Twain, Mark                            19
# Dickens, Charles                       18
# Doyle, Arthur Conan                    13
#                                        ..
# Patanjali                               1
# Windsor, H. H. (Henry Haven)            1
# Lippmann, Walter                        1
# Leadbeater, C. W. (Charles Webster)     1
# Hamsun, Knut                            1
# Name: count, Length: 422, dtype: int64

# %% [markdown]
# **g) Calcular idade do autor à data de publicação**
# - **Objetivo:** Criar uma nova coluna com a idade do autor aquando da publicação.

# %%
df_eng["Idade_Publicacao"] = df_eng["bibliography.publication.year"] - df_eng["bibliography.author.birth"]
df_eng
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18164\895638449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eng["Idade_Publicacao"] = df_eng["bibliography.publication.year"] - df_eng["bibliography.author.birth"]
#     bibliography.congress classifications bibliography.languages  \
# 0                                      PR                     en
# 1                                      PS                     en
# 2                                   PZ,PR                     en
# 3                                      PR                     en
# 4                                      PT                     en
# ..                                    ...                    ...
# ...

# %% [markdown]
# **h) Substituir os valores a zero no Downloads pela mediana**
#
# - **Objetivo:** Substituir valores que são zero pela mediana.

# %%
df_eng.fillna(df_eng.median, inplace=True)
df_eng
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18164\1359299285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eng.fillna(df_eng.median, inplace=True)
#     bibliography.congress classifications bibliography.languages  \
# 0                                      PR                     en
# 1                                      PS                     en
# 2                                   PZ,PR                     en
# 3                                      PR                     en
# 4                                      PT                     en
# ..                                    ...                    ...
# 985                                    PR                     en
# 986                                    GR                     en
# ...

# %% [markdown]
# **h) Criar coluna com número médio de letras por frase**
# - **Objetivo:** Derivar uma nova métrica com base nas estatísticas de caracteres e frases.

# %%
df_eng.columns
# Out:
# Index(['bibliography.congress classifications', 'bibliography.languages',
#        'bibliography.subjects', 'bibliography.title', 'bibliography.type',
#        'metadata.downloads', 'metadata.id', 'metadata.rank', 'metadata.url',
#        'bibliography.author.birth', 'bibliography.author.death',
#        'bibliography.author.name', 'bibliography.publication.day',
#        'bibliography.publication.full', 'bibliography.publication.month',
#        'bibliography.publication.month name', 'bibliography.publication.year',
#        'metadata.formats.total', 'metadata.formats.types',
#        'metrics.difficulty.automated readability index',
#        'metrics.difficulty.coleman liau index',
#        'metrics.difficulty.dale chall readability score',
#        'metrics.difficulty.difficult words',
#        'metrics.difficulty.flesch kincaid grade',
#        'metrics.difficulty.flesch reading ease',
#        'metrics.difficulty.gunning fog',
# ...

# %%
df_eng["NumeroMedioLetrasPalavra"] = df_eng['metrics.statistics.characters'] / df_eng['metrics.statistics.sentences']
df_eng
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18164\1148202172.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eng["NumeroMedioLetrasPalavra"] = df_eng['metrics.statistics.characters'] / df_eng['metrics.statistics.sentences']
#     bibliography.congress classifications bibliography.languages  \
# 0                                      PR                     en
# 1                                      PS                     en
# 2                                   PZ,PR                     en
# 3                                      PR                     en
# 4                                      PT                     en
# ..                                    ...                    ...
# ...

# %% [markdown]
# **i) Agrupar por século de publicação**
# - **Objetivo:** Criar uma nova coluna com o século e contar quantas obras há por século.

# %%
df_eng["SeculoPublicacao"] = (df_eng['bibliography.publication.year'] - 1 // 100) + 1
df_eng
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18164\2932543444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eng["SeculoPublicacao"] = (df_eng['bibliography.publication.year'] - 1 // 100) + 1
#     bibliography.congress classifications bibliography.languages  \
# 0                                      PR                     en
# 1                                      PS                     en
# 2                                   PZ,PR                     en
# 3                                      PR                     en
# 4                                      PT                     en
# ..                                    ...                    ...
# 985                                    PR                     en
# ...

# %% [markdown]
# ### Parte II - Matplotlib

# %%
df_eng.columns
# Out:
# Index(['bibliography.congress classifications', 'bibliography.languages',
#        'bibliography.subjects', 'bibliography.title', 'bibliography.type',
#        'metadata.downloads', 'metadata.id', 'metadata.rank', 'metadata.url',
#        'bibliography.author.birth', 'bibliography.author.death',
#        'bibliography.author.name', 'bibliography.publication.day',
#        'bibliography.publication.full', 'bibliography.publication.month',
#        'bibliography.publication.month name', 'bibliography.publication.year',
#        'metadata.formats.total', 'metadata.formats.types',
#        'metrics.difficulty.automated readability index',
#        'metrics.difficulty.coleman liau index',
#        'metrics.difficulty.dale chall readability score',
#        'metrics.difficulty.difficult words',
#        'metrics.difficulty.flesch kincaid grade',
#        'metrics.difficulty.flesch reading ease',
#        'metrics.difficulty.gunning fog',
# ...

# %% [markdown]
# **a) Correlação entre dificuldade de leitura e número de palavras**
# - **Objetivo:** Explorar se livros com mais palavras tendem a ser mais difíceis de ler.
# - **Gráfico sugerido:** Diagrama de dispersão (scatterplot).

# %%
plot_scatter_sns(df_eng["metrics.statistics.words"], df_eng["metrics.difficulty.flesch reading ease"], titulo='dificuldade de leitura e número de palavras', xlabel='Comprimento da Palavra', ylabel='Frequência')

# %% [markdown]
# **b) Popularidade vs. Facilidade de leitura**
# - **Objetivo:** Ver se os livros mais descarregados são os mais fáceis de ler.
# - **Gráfico sugerido:** Gráfico de dispersão.

# %%
plot_scatter_sns(df_eng["metadata.downloads"], df_eng["metrics.difficulty.difficult words"], titulo='dificuldade de leitura e número de palavras', xlabel='Comprimento da Palavra', ylabel='Frequência')

# %% [markdown]
# **c) Evolução da complexidade ao longo dos anos**
# - **Objetivo:** Analisar se a dificuldade dos livros aumentou ou diminuiu com os anos de publicação.
# - **Gráfico sugerido:** Gráfico de linhas.

# %%
df_eng.columns
# Out:
# Index(['bibliography.congress classifications', 'bibliography.languages',
#        'bibliography.subjects', 'bibliography.title', 'bibliography.type',
#        'metadata.downloads', 'metadata.id', 'metadata.rank', 'metadata.url',
#        'bibliography.author.birth', 'bibliography.author.death',
#        'bibliography.author.name', 'bibliography.publication.day',
#        'bibliography.publication.full', 'bibliography.publication.month',
#        'bibliography.publication.month name', 'bibliography.publication.year',
#        'metadata.formats.total', 'metadata.formats.types',
#        'metrics.difficulty.automated readability index',
#        'metrics.difficulty.coleman liau index',
#        'metrics.difficulty.dale chall readability score',
#        'metrics.difficulty.difficult words',
#        'metrics.difficulty.flesch kincaid grade',
#        'metrics.difficulty.flesch reading ease',
#        'metrics.difficulty.gunning fog',
# ...

# %%
teste = df_eng.groupby("bibliography.publication.year")["metrics.difficulty.flesch reading ease"].mean()
teste
# Out:
# bibliography.publication.year
# 1422    73.510000
# 1475    66.410000
# 1517    44.750000
# 1590    83.660000
# 1597    81.630000
# 1600    80.620000
# 1603    81.125000
# 1608    94.150000
# 1622    83.660000
# 1623    80.617500
# 1776    74.860000
# 1837    72.160000
# 1848    77.570000
# 1870    71.145000
# 1873    70.130000
# 1888    78.590000
# 1892    80.620000
# 1895    46.100000
# 1911    61.670000
# 1922    78.590000
# 1991    72.632000
# 1992    70.094000
# 1993    70.552500
# 1994    73.398333
# 1995    73.991667
# 1996    72.320741
# 1997    69.356250
# 1998    71.397143
# 1999    68.874815
# 2000    74.549333
# 2001    70.422174
# 2002    68.369333
# 2003    70.063243
# 2004    65.965472
# 2005    68.060111
# 2006    68.606990
# 2007    71.005946
# 2008    69.075278
# 2009    67.412500
# 2010    67.889231
# 2011    66.276154
# 2012    64.826190
# 2013    71.094286
# 2014    68.321667
# 2015    74.076667
# 2016    84.680000
# ...

# %%
plot_lineplot_sns(teste.index, teste.values, titulo='dificuldade de leitura e número de palavras')

# %% [markdown]
# **d) Dificuldade Média por Autor**
# - **Objetivo:** Identificar quais os autores mais frequentes e comparar a dificuldade média dos seus livros.
# - **Gráfico sugerido:** Gráfico de barras.

# %%
top10 = list(df_eng["bibliography.author.name"].value_counts().head(10).index)
top10
# Out:
# ['Unknown',
#  'Shakespeare, William',
#  'Twain, Mark',
#  'Dickens, Charles',
#  'Doyle, Arthur Conan',
#  'Wilde, Oscar',
#  'Plato',
#  'Austen, Jane',
#  'Chesterton, G. K. (Gilbert Keith)',
#  'Dick, Philip K.']

# %%
df_exercicioD = df_eng[df_eng["bibliography.author.name"].isin(top10)].groupby("bibliography.author.name")["metrics.difficulty.flesch reading ease"].mean()
df_exercicioD
# Out:
# bibliography.author.name
# Austen, Jane                         67.359091
# Chesterton, G. K. (Gilbert Keith)    69.188889
# Dick, Philip K.                      86.856667
# Dickens, Charles                     75.203333
# Doyle, Arthur Conan                  79.368462
# Plato                                61.730909
# Shakespeare, William                 83.039474
# Twain, Mark                          72.977895
# Unknown                              74.093437
# Wilde, Oscar                         77.769167
# Name: metrics.difficulty.flesch reading ease, dtype: float64

# %%
plot_barplot_sns(df_exercicioD.index, df_exercicioD.values, titulo='dificuldade de leitura e número de palavras', horizontal=True)
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18164\886664114.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=frequencias, y=palavras, palette="viridis")

# %% [markdown]
# **e) Exploração**
# - **Objetivo:** Usar gráficos para procurar padrões ou correlações entre métricas (tamanho, dificuldade, polaridade, etc.)
